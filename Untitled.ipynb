# %%
from pprint import pprint


catalog = []

cars= [{
        "марка-модель": ("Mercedes", "s"),
        "характеристики":{
        "цена": 18100,  #в долларах
        "двигатель": 3,
        "привод": "задний",
        "разгон до 100": 6.2,
        "выпуск": 2018,
        "страна": "Германия"
        }
        },
        {
            "марка-модель": ("Toyota", "Camri"),
            "характеристики": {
            "цена": 29300, 
            "двигатель": 3,
            "привод": "передний",
            "разгон до 100": 6.8,
            "выпуск": 2017,
            "страна": "Япония"
            }
        },
        {
            "марка-модель": ("Volksvagen", "Kafer"),
            "характеристики": {
            "цена": 3500, 
            "двигатель": 3,
            "привод": "полный",
            "разгон до 100": 6.7,
            "выпуск": 2003,
            "страна": "Германия"}
        },
        {
            "марка-модель": ("Moskvich", "3"),
            "характеристики": {
            "цена": 10400, 
            "двигатель": 3,
            "привод": "передний",
            "разгон до 100": 11,
            "выпуск": 2022,
            "страна": "Китай"} # Как разозлить весь российский автопром в 1 строк
        },
        {
            "марка-модель": ("Lamborgini", "Urus"),
            "характеристики": {
            "цена": 205200, 
            "двигатель": 4,
            "привод": "полный",
            "разгон до 100": 3.3,
            "выпуск": 2018,
            "страна": "Италия"}
        },
        {
            "марка-модель": ("Kia", "Rio"),
            "характеристики": {
            "цена": 11600, 
            "двигатель": 1.6,
            "привод": "передний",
            "разгон до 100": 10.3,
            "выпуск": 2017,
            "страна": "Республика Корея"}
        },
        {
            "марка-модель": ("Hyundai Solaris", "s"),
            "характеристики": {
            "цена": 14295, 
            "двигатель": 1.6,
            "привод": "передний",
            "разгон до 100": 10.3,
            "выпуск": 2022,
            "страна": "Республика Корея"}
        },
        {
            "марка-модель": ("Lada", "Granta"),
            "характеристики": {
            "цена": 6600, 
            "двигатель": 3,
            "привод": "задний",
            "разгон до 100": 10.5,
            "выпуск": 2019,
            "страна": "Россия"}
        },
        {
            "марка-модель": ("zhiguli", "VAZ 2101"),
            "характеристики": {
            "цена": 400, 
            "двигатель": 3,
            "привод": "задний",
            "разгон до 100": 18.0,
            "выпуск": 1970,
            "страна": "Союз Советских Социалистических Республик (СССР)"}
        }
]

catalog.extend(cars)
for car in catalog: 
   car["рассрочка"] = True


def prepare(dict, param, criterion):
    show = []
    for car in dict:
        if  and param == "цена" and car["характеристики"][param] <= criterion:
            show.append(car["марка-модель"])
        elif type(car["характеристики"][param]) != 'int' and car["характеристики"][param] == criterion:
            show.append(car["марка-модель"])
    pprint(show)

prepare(catalog, "привод", "передний")
# Out:
# [('Toyota', 'Camri'),
#  ('Moskvich', '3'),
#  ('Kia', 'Rio'),
#  ('Hyundai Solaris', 's')]
